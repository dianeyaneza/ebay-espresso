# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import seaborn as sns

# Flight data files
data_path = "../resources/cleansheet1_with_airline.csv"

# Read the flight data
flight_airline_data = pd.read_csv(data_path)
flight_airline_data
# Out:
#         Month     Scheduled Operator Country to/from Passengers In Freight In  \
# 0      Jan009  Aerolineas Argentinas       Argentina         3,021        4.3
# 1      Jan009  Aerolineas Argentinas     New Zealand           627       76.3
# 2      Jan009          Air Caledonie   New Caledonia         6,658        4.9
# 3      Jan009             Air Canada          Canada         7,489      174.8
# 4      Jan009              Air China           China        12,458      201.3
# ...       ...                    ...             ...           ...        ...
# 15052  Nov020  United Parcel Service           Korea            ..         ..
# 15053  Nov020  United Parcel Service       Singapore            ..         ..
# 15054  Nov020  United Parcel Service             USA            ..    1,484.4
# 15055  Nov020       Vietnam Airlines         Vietnam           248      437.1
# 15056  Nov020        Xiamen Airlines           China           272      144.1
#
#       Mail In Passengers Out Freight Out Mail Out  Year
# 0         0.6          1,959         8.3      0.0  2009
# 1         0.0          1,821        68.5      0.0  2009
# 2         0.6          5,365        68.6      1.3  2009
# 3         0.0          6,424       105.2      0.0  2009
# 4        18.6         11,163       142.4      2.9  2009
# ...       ...            ...         ...      ...   ...
# 15052      ..             ..       254.8      0.0  2020
# 15053      ..             ..        28.9      0.0  2020
# 15054     0.0             ..          ..       ..  2020
# 15055     0.0            691       534.2      8.8  2020
# 15056     6.6          2,450       118.2      0.0  2020
#
# [15057 rows x 10 columns]

# %%
#Remove commas in figures and convert to float
clean_flight_airline_data = flight_airline_data
clean_flight_airline_data["Passengers In"]= clean_flight_airline_data["Passengers In"].str.replace(",","").replace("..","0").astype(float)

clean_flight_airline_data
# Out:
#         Month     Scheduled Operator Country to/from  Passengers In  \
# 0      Jan009  Aerolineas Argentinas       Argentina         3021.0
# 1      Jan009  Aerolineas Argentinas     New Zealand          627.0
# 2      Jan009          Air Caledonie   New Caledonia         6658.0
# 3      Jan009             Air Canada          Canada         7489.0
# 4      Jan009              Air China           China        12458.0
# ...       ...                    ...             ...            ...
# 15052  Nov020  United Parcel Service           Korea            0.0
# 15053  Nov020  United Parcel Service       Singapore            0.0
# 15054  Nov020  United Parcel Service             USA            0.0
# 15055  Nov020       Vietnam Airlines         Vietnam          248.0
# 15056  Nov020        Xiamen Airlines           China          272.0
#
#       Freight In Mail In Passengers Out Freight Out Mail Out  Year
# 0            4.3     0.6          1,959         8.3      0.0  2009
# 1           76.3     0.0          1,821        68.5      0.0  2009
# 2            4.9     0.6          5,365        68.6      1.3  2009
# 3          174.8     0.0          6,424       105.2      0.0  2009
# 4          201.3    18.6         11,163       142.4      2.9  2009
# ...          ...     ...            ...         ...      ...   ...
# 15052         ..      ..             ..       254.8      0.0  2020
# 15053         ..      ..             ..        28.9      0.0  2020
# 15054    1,484.4     0.0             ..          ..       ..  2020
# 15055      437.1     0.0            691       534.2      8.8  2020
# 15056      144.1     6.6          2,450       118.2      0.0  2020
#
# [15057 rows x 10 columns]

# %%
#Remove commas in figures and convert to float
clean_flight_airline_data["Passengers Out"]= clean_flight_airline_data["Passengers Out"].str.replace(",","").replace("..","0").astype(float)
clean_flight_airline_data
# Out:
#         Month     Scheduled Operator Country to/from  Passengers In  \
# 0      Jan009  Aerolineas Argentinas       Argentina         3021.0
# 1      Jan009  Aerolineas Argentinas     New Zealand          627.0
# 2      Jan009          Air Caledonie   New Caledonia         6658.0
# 3      Jan009             Air Canada          Canada         7489.0
# 4      Jan009              Air China           China        12458.0
# ...       ...                    ...             ...            ...
# 15052  Nov020  United Parcel Service           Korea            0.0
# 15053  Nov020  United Parcel Service       Singapore            0.0
# 15054  Nov020  United Parcel Service             USA            0.0
# 15055  Nov020       Vietnam Airlines         Vietnam          248.0
# 15056  Nov020        Xiamen Airlines           China          272.0
#
#       Freight In Mail In  Passengers Out Freight Out Mail Out  Year
# 0            4.3     0.6          1959.0         8.3      0.0  2009
# 1           76.3     0.0          1821.0        68.5      0.0  2009
# 2            4.9     0.6          5365.0        68.6      1.3  2009
# 3          174.8     0.0          6424.0       105.2      0.0  2009
# 4          201.3    18.6         11163.0       142.4      2.9  2009
# ...          ...     ...             ...         ...      ...   ...
# 15052         ..      ..             0.0       254.8      0.0  2020
# 15053         ..      ..             0.0        28.9      0.0  2020
# 15054    1,484.4     0.0             0.0          ..       ..  2020
# 15055      437.1     0.0           691.0       534.2      8.8  2020
# 15056      144.1     6.6          2450.0       118.2      0.0  2020
#
# [15057 rows x 10 columns]

# %%
#Replace fields containing no data '..' with 0
clean_flight_airline_data["Mail In"]= clean_flight_airline_data["Mail In"].str.replace("..","0").astype(float)
clean_flight_airline_data["Mail Out"]= clean_flight_airline_data["Mail Out"].str.replace("..","0").astype(float)
clean_flight_airline_data["Freight In"]= clean_flight_airline_data["Freight In"].str.replace(",","").replace("..","0").astype(float)
clean_flight_airline_data["Freight Out"]= clean_flight_airline_data["Freight Out"].str.replace(",","").replace("..","0").astype(float)
clean_flight_airline_data
# Out:
#         Month     Scheduled Operator Country to/from  Passengers In  \
# 0      Jan009  Aerolineas Argentinas       Argentina         3021.0
# 1      Jan009  Aerolineas Argentinas     New Zealand          627.0
# 2      Jan009          Air Caledonie   New Caledonia         6658.0
# 3      Jan009             Air Canada          Canada         7489.0
# 4      Jan009              Air China           China        12458.0
# ...       ...                    ...             ...            ...
# 15052  Nov020  United Parcel Service           Korea            0.0
# 15053  Nov020  United Parcel Service       Singapore            0.0
# 15054  Nov020  United Parcel Service             USA            0.0
# 15055  Nov020       Vietnam Airlines         Vietnam          248.0
# 15056  Nov020        Xiamen Airlines           China          272.0
#
#        Freight In  Mail In  Passengers Out  Freight Out  Mail Out  Year
# 0             4.3      6.0          1959.0          8.3       0.0  2009
# 1            76.3      0.0          1821.0         68.5       0.0  2009
# 2             4.9      6.0          5365.0         68.6       3.0  2009
# 3           174.8      0.0          6424.0        105.2       0.0  2009
# 4           201.3      0.0         11163.0        142.4       9.0  2009
# ...           ...      ...             ...          ...       ...   ...
# 15052         0.0      0.0             0.0        254.8       0.0  2020
# 15053         0.0      0.0             0.0         28.9       0.0  2020
# 15054      1484.4      0.0             0.0          0.0       0.0  2020
# 15055       437.1      0.0           691.0        534.2       8.0  2020
# 15056       144.1      6.0          2450.0        118.2       0.0  2020
#
# [15057 rows x 10 columns]

# %%
#Check column types to verify data types and conversion
clean_flight_airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15057 entries, 0 to 15056
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Month               15057 non-null  object
#  1   Scheduled Operator  15057 non-null  object
#  2   Country to/from     15057 non-null  object
#  3   Passengers In       15057 non-null  float64
#  4   Freight In          15057 non-null  float64
#  5   Mail In             15057 non-null  float64
#  6   Passengers Out      15057 non-null  float64
#  7   Freight Out         15057 non-null  float64
#  8   Mail Out            15057 non-null  float64
#  9   Year                15057 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 1.1+ MB

# %%
#Calculate Passenger, Mail & Freight In and Out numbers
clean_flight_airline_data["Passengers_Total"] = clean_flight_airline_data["Passengers In"] + clean_flight_airline_data["Passengers Out"]
clean_flight_airline_data["Freight_Total"] = clean_flight_airline_data["Freight In"] + clean_flight_airline_data["Freight Out"]
clean_flight_airline_data["Mail_Total"] = clean_flight_airline_data["Mail In"] + clean_flight_airline_data["Mail Out"]

#Combine Freight and Mail totals for easy comparison against passenger numbers
clean_flight_airline_data["Freight_Mail_Total"] = clean_flight_airline_data["Mail_Total"] + clean_flight_airline_data["Freight_Total"]
clean_flight_airline_data
# Out:
#         Month     Scheduled Operator Country to/from  Passengers In  \
# 0      Jan009  Aerolineas Argentinas       Argentina         3021.0
# 1      Jan009  Aerolineas Argentinas     New Zealand          627.0
# 2      Jan009          Air Caledonie   New Caledonia         6658.0
# 3      Jan009             Air Canada          Canada         7489.0
# 4      Jan009              Air China           China        12458.0
# ...       ...                    ...             ...            ...
# 15052  Nov020  United Parcel Service           Korea            0.0
# 15053  Nov020  United Parcel Service       Singapore            0.0
# 15054  Nov020  United Parcel Service             USA            0.0
# 15055  Nov020       Vietnam Airlines         Vietnam          248.0
# 15056  Nov020        Xiamen Airlines           China          272.0
#
#        Freight In  Mail In  Passengers Out  Freight Out  Mail Out  Year  \
# 0             4.3      6.0          1959.0          8.3       0.0  2009
# 1            76.3      0.0          1821.0         68.5       0.0  2009
# 2             4.9      6.0          5365.0         68.6       3.0  2009
# 3           174.8      0.0          6424.0        105.2       0.0  2009
# 4           201.3      0.0         11163.0        142.4       9.0  2009
# ...           ...      ...             ...          ...       ...   ...
# 15052         0.0      0.0             0.0        254.8       0.0  2020
# 15053         0.0      0.0             0.0         28.9       0.0  2020
# 15054      1484.4      0.0             0.0          0.0       0.0  2020
# 15055       437.1      0.0           691.0        534.2       8.0  2020
# 15056       144.1      6.0          2450.0        118.2       0.0  2020
#
#        Passengers_Total  Freight_Total  Mail_Total  Freight_Mail_Total
# 0                4980.0           12.6         6.0                18.6
# 1                2448.0          144.8         0.0               144.8
# 2               12023.0           73.5         9.0                82.5
# 3               13913.0          280.0         0.0               280.0
# 4               23621.0          343.7         9.0               352.7
# ...                 ...            ...         ...                 ...
# 15052               0.0          254.8         0.0               254.8
# 15053               0.0           28.9         0.0                28.9
# 15054               0.0         1484.4         0.0              1484.4
# 15055             939.0          971.3         8.0               979.3
# 15056            2722.0          262.3         6.0               268.3
#
# [15057 rows x 14 columns]

# %%
#Remove unused columns
clean_flight_airline_data = clean_flight_airline_data.drop(columns=["Country to/from","Freight In","Freight Out", "Mail In", "Mail Out", "Passengers In", "Passengers Out", "Freight_Total", "Mail_Total"])
clean_flight_airline_data
# Out:
#         Month     Scheduled Operator  Year  Passengers_Total  \
# 0      Jan009  Aerolineas Argentinas  2009            4980.0
# 1      Jan009  Aerolineas Argentinas  2009            2448.0
# 2      Jan009          Air Caledonie  2009           12023.0
# 3      Jan009             Air Canada  2009           13913.0
# 4      Jan009              Air China  2009           23621.0
# ...       ...                    ...   ...               ...
# 15052  Nov020  United Parcel Service  2020               0.0
# 15053  Nov020  United Parcel Service  2020               0.0
# 15054  Nov020  United Parcel Service  2020               0.0
# 15055  Nov020       Vietnam Airlines  2020             939.0
# 15056  Nov020        Xiamen Airlines  2020            2722.0
#
#        Freight_Mail_Total
# 0                    18.6
# 1                   144.8
# 2                    82.5
# 3                   280.0
# 4                   352.7
# ...                   ...
# 15052               254.8
# 15053                28.9
# 15054              1484.4
# 15055               979.3
# 15056               268.3
#
# [15057 rows x 5 columns]

# %%
# grouped_airline_flight_df = clean_flight_airline_data.groupby(["Scheduled Operator","Month","Year" ], as_index=False)
grouped_airline_flight_df = clean_flight_airline_data.drop(columns="Year")
grouped_airline_flight_df = grouped_airline_flight_df.groupby(["Scheduled Operator"])

#Get top airlines by total Freight and Mail weight
# top_freight_mail_airlines_df = grouped_airline_flight_df.sum().sort_values("Freight_Mail_Total", ascending=False)[:5]
top_freight_mail_airlines_df = grouped_airline_flight_df.sum().sort_values("Freight_Mail_Total", ascending=False)
top_freight_mail_airlines_df["Freight_Mail_Total"]
# Out:
# Scheduled Operator
# Singapore Airlines        1786615.7
# Qantas Airways            1579914.5
# Emirates                  1156326.2
# Cathay Pacific Airways     900142.0
# Air New Zealand            580691.3
#                             ...
# Tiger Airways                   0.0
# OzJet                           0.0
# Airnorth                        0.0
# Batik Air Indonesia             0.0
# SkyAirWorld                     0.0
# Name: Freight_Mail_Total, Length: 90, dtype: float64

# %%
### Observation: Singaporean Airlines carried the most freight ove the last 10yrs closely followed by Qantas Airlines
top_freight_mail_airlines_df["Freight_Mail_Total"].plot.bar(alpha=0.7, colormap="summer")
plt.legend(loc="best")
plt.title("Top Airlines by Freight & Mail")
plt.xlabel("Top Airlines")
plt.ylabel("Weight (Tonnes)")
# Out:
# Text(0, 0.5, 'Weight (Tonnes)')

# %%
# Save list of top airlines by Freight and Mail weight (tonnes) since 2009
top_freight_mail_airlines_list = top_freight_mail_airlines_df.index
top_freight_mail_airlines_list
# Out:
# Index(['Singapore Airlines', 'Qantas Airways', 'Emirates',
#        'Cathay Pacific Airways', 'Air New Zealand', 'Malaysia Airlines',
#        'Thai Airways International', 'Etihad Airways',
#        'Federal Express Corporation', 'Qatar Airways',
#        'China Southern Airlines', 'United Parcel Service', 'Jetstar',
#        'Virgin Australia', 'China Eastern Airlines', 'AirAsia X',
#        'Garuda Indonesia', 'Tasman Cargo Airlines', 'United Airlines',
#        'Air China', 'China Airlines', 'Vietnam Airlines', 'Korean Air',
#        'Polar Air Cargo', 'British Airways', 'Delta Air Lines',
#        'Royal Brunei Airlines', 'Air Canada', 'Fiji Airways',
#        'Philippine Airlines', 'Japan Airlines', 'Scoot',
#        'Virgin Atlantic Airways', 'All Nippon Airways', 'Air Niugini',
#        'South African Airways', 'Xiamen Airlines', 'Asiana Airlines',
#        'LAN Airlines', 'Eva Air', 'Hawaiian Airlines', 'Scoot Tigerair',
#        'Hainan Airlines', 'LATAM Airlines', 'V Australia', 'Kalitta Air',
#        'Cebu Pacific Air', 'American Airlines', 'Air India',
#        'Pacific Air Express', 'SriLankan Airlines', 'Beijing Capital Airlines',
#        'Air Pacific', 'JALways', 'Sichuan Airlines', 'Air Mauritius',
#        'Hong Kong Airlines', 'Air Caledonie International',
#        'Aerolineas Argentinas', 'Air Vanuatu', 'Tianjin Airlines',
#        'Nauru Airlines', 'Cargolux Airlines Intl', 'Air Caledonie',
#        'Solomon Airlines', 'Silk Air', 'Indonesia AirAsia Extra',
#        'Air Austral', 'Jetstar Asia', 'Indonesia AirAsia', 'Our Airline',
#        'Virgin Samoa', 'Airlines PNG', 'Thai AirAsia X', 'Citilink Indonesia',
#        'Air Tahiti Nui', 'Air Australia', 'Donghai Airlines', 'Malindo Air',
#        'Jin Air', 'Samoa Airways', 'Continental Micronesia', 'Air Chathams',
#        'Tigerair', 'Tigerair Australia', 'Tiger Airways', 'OzJet', 'Airnorth',
#        'Batik Air Indonesia', 'SkyAirWorld'],
#       dtype='object', name='Scheduled Operator')

# %%
#Get top airlines by total number of passengers travelled since 2009
# top_passenger_airlines_df = grouped_airline_flight_df.sum().sort_values("Passengers_Total", ascending=False)[:5]
top_passenger_airlines_df = grouped_airline_flight_df.sum().sort_values("Passengers_Total", ascending=False)
top_passenger_airlines_df["Passengers_Total"]
top_passenger_airlines_df["Passengers_Total"].plot.bar(alpha=0.7, colormap="winter")
plt.legend(loc="best")
plt.title("Top Airlines by Passengers")
plt.xlabel("Top Airlines")
plt.ylabel("Passengers (Millions)")
# Out:
# Text(0, 0.5, 'Passengers (Millions)')

# %%
### Observation: Quantas Airlines carries at least double the number passengers compared to any other airline.
# Save list of top airlines by passengers carried
top_passenger_airlines_list = top_passenger_airlines_df.index
top_passenger_airlines_list
# Out:
# Index(['Qantas Airways', 'Singapore Airlines', 'Jetstar', 'Emirates',
#        'Air New Zealand', 'Virgin Australia', 'Cathay Pacific Airways',
#        'Malaysia Airlines', 'AirAsia X', 'Thai Airways International',
#        'Etihad Airways', 'China Southern Airlines', 'Garuda Indonesia',
#        'Qatar Airways', 'China Eastern Airlines', 'United Airlines',
#        'Fiji Airways', 'Air China', 'Indonesia AirAsia', 'China Airlines',
#        'Vietnam Airlines', 'Korean Air', 'Air Canada', 'Scoot',
#        'British Airways', 'Philippine Airlines', 'Hawaiian Airlines',
#        'Air Niugini', 'Asiana Airlines', 'Scoot Tigerair', 'Delta Air Lines',
#        'Royal Brunei Airlines', 'Japan Airlines', 'Jetstar Asia',
#        'South African Airways', 'V Australia', 'Air Vanuatu', 'Malindo Air',
#        'Air India', 'Cebu Pacific Air', 'LAN Airlines',
#        'Virgin Atlantic Airways', 'Air Caledonie International',
#        'American Airlines', 'Air Pacific', 'Hainan Airlines',
#        'Xiamen Airlines', 'LATAM Airlines', 'Eva Air', 'Silk Air',
#        'All Nippon Airways', 'Sichuan Airlines', 'Air Mauritius', 'JALways',
#        'Tigerair', 'SriLankan Airlines', 'Virgin Samoa', 'Solomon Airlines',
#        'Air Caledonie', 'Aerolineas Argentinas', 'Indonesia AirAsia Extra',
#        'Batik Air Indonesia', 'Beijing Capital Airlines', 'Tigerair Australia',
#        'Tiger Airways', 'Air Australia', 'Hong Kong Airlines',
#        'Tianjin Airlines', 'Nauru Airlines', 'Continental Micronesia',
#        'Air Austral', 'Samoa Airways', 'Thai AirAsia X', 'Our Airline',
#        'Airlines PNG', 'Citilink Indonesia', 'Jin Air', 'Donghai Airlines',
#        'Air Tahiti Nui', 'OzJet', 'Air Chathams', 'SkyAirWorld', 'Airnorth',
#        'Tasman Cargo Airlines', 'United Parcel Service', 'Polar Air Cargo',
#        'Pacific Air Express', 'Cargolux Airlines Intl',
#        'Federal Express Corporation', 'Kalitta Air'],
#       dtype='object', name='Scheduled Operator')

# %%
#Combine top airlines for freight-mail and passengers
top_airlines_combined_list = top_passenger_airlines_list.append(top_freight_mail_airlines_list)

top_airlines_combined_list = top_airlines_combined_list.unique()
top_airlines_combined_list
# Out:
# Index(['Qantas Airways', 'Singapore Airlines', 'Jetstar', 'Emirates',
#        'Air New Zealand', 'Virgin Australia', 'Cathay Pacific Airways',
#        'Malaysia Airlines', 'AirAsia X', 'Thai Airways International',
#        'Etihad Airways', 'China Southern Airlines', 'Garuda Indonesia',
#        'Qatar Airways', 'China Eastern Airlines', 'United Airlines',
#        'Fiji Airways', 'Air China', 'Indonesia AirAsia', 'China Airlines',
#        'Vietnam Airlines', 'Korean Air', 'Air Canada', 'Scoot',
#        'British Airways', 'Philippine Airlines', 'Hawaiian Airlines',
#        'Air Niugini', 'Asiana Airlines', 'Scoot Tigerair', 'Delta Air Lines',
#        'Royal Brunei Airlines', 'Japan Airlines', 'Jetstar Asia',
#        'South African Airways', 'V Australia', 'Air Vanuatu', 'Malindo Air',
#        'Air India', 'Cebu Pacific Air', 'LAN Airlines',
#        'Virgin Atlantic Airways', 'Air Caledonie International',
#        'American Airlines', 'Air Pacific', 'Hainan Airlines',
#        'Xiamen Airlines', 'LATAM Airlines', 'Eva Air', 'Silk Air',
#        'All Nippon Airways', 'Sichuan Airlines', 'Air Mauritius', 'JALways',
#        'Tigerair', 'SriLankan Airlines', 'Virgin Samoa', 'Solomon Airlines',
#        'Air Caledonie', 'Aerolineas Argentinas', 'Indonesia AirAsia Extra',
#        'Batik Air Indonesia', 'Beijing Capital Airlines', 'Tigerair Australia',
#        'Tiger Airways', 'Air Australia', 'Hong Kong Airlines',
#        'Tianjin Airlines', 'Nauru Airlines', 'Continental Micronesia',
#        'Air Austral', 'Samoa Airways', 'Thai AirAsia X', 'Our Airline',
#        'Airlines PNG', 'Citilink Indonesia', 'Jin Air', 'Donghai Airlines',
#        'Air Tahiti Nui', 'OzJet', 'Air Chathams', 'SkyAirWorld', 'Airnorth',
#        'Tasman Cargo Airlines', 'United Parcel Service', 'Polar Air Cargo',
#        'Pacific Air Express', 'Cargolux Airlines Intl',
#        'Federal Express Corporation', 'Kalitta Air'],
#       dtype='object', name='Scheduled Operator')

# %%
# Filter top airline data using list of top airlines i.e. highest cargo and passenger to date
top_airlines_flight_data_df = clean_flight_airline_data[clean_flight_airline_data["Scheduled Operator"].isin(top_airlines_combined_list)]
#Filter by data later than 2019
top_airlines_flight_data_df = top_airlines_flight_data_df.loc[top_airlines_flight_data_df.Year >= 2019]
# top_airlines_flight_data_df = top_airlines_flight_data_df.drop(columns="Year")
top_airlines_flight_data_df
# Out:
#         Month           Scheduled Operator  Year  Passengers_Total  \
# 12671  Dec018  Air Caledonie International  2019           13053.0
# 12672  Dec018                   Air Canada  2019           36027.0
# 12673  Dec018                    Air China  2019           50119.0
# 12674  Dec018                    Air India  2019           16799.0
# 12675  Dec018                Air Mauritius  2019            6792.0
# ...       ...                          ...   ...               ...
# 15052  Nov020        United Parcel Service  2020               0.0
# 15053  Nov020        United Parcel Service  2020               0.0
# 15054  Nov020        United Parcel Service  2020               0.0
# 15055  Nov020             Vietnam Airlines  2020             939.0
# 15056  Nov020              Xiamen Airlines  2020            2722.0
#
#        Freight_Mail_Total
# 12671                93.0
# 12672               706.9
# 12673              1278.0
# 12674               320.9
# 12675               135.3
# ...                   ...
# 15052               254.8
# 15053                28.9
# 15054              1484.4
# 15055               979.3
# 15056               268.3
#
# [2386 rows x 5 columns]

# %%
# Filter top airline data using list of top airlines i.e. highest cargo and passenger to date
top_airlines_flight_data_df = clean_flight_airline_data[clean_flight_airline_data["Scheduled Operator"].isin(top_airlines_combined_list)]
#Filter by data later than 2019
top_airlines_flight_data_df = top_airlines_flight_data_df.loc[top_airlines_flight_data_df.Year >= 2019]
# top_airlines_flight_data_df = top_airlines_flight_data_df.drop(columns="Year")
top_airlines_flight_data_df
# Out:
#         Month           Scheduled Operator  Year  Passengers_Total  \
# 12671  Dec018  Air Caledonie International  2019           13053.0
# 12672  Dec018                   Air Canada  2019           36027.0
# 12673  Dec018                    Air China  2019           50119.0
# 12674  Dec018                    Air India  2019           16799.0
# 12675  Dec018                Air Mauritius  2019            6792.0
# ...       ...                          ...   ...               ...
# 15052  Nov020        United Parcel Service  2020               0.0
# 15053  Nov020        United Parcel Service  2020               0.0
# 15054  Nov020        United Parcel Service  2020               0.0
# 15055  Nov020             Vietnam Airlines  2020             939.0
# 15056  Nov020              Xiamen Airlines  2020            2722.0
#
#        Freight_Mail_Total
# 12671                93.0
# 12672               706.9
# 12673              1278.0
# 12674               320.9
# 12675               135.3
# ...                   ...
# 15052               254.8
# 15053                28.9
# 15054              1484.4
# 15055               979.3
# 15056               268.3
#
# [2386 rows x 5 columns]

# %%
#Dataframe for comparison between 2020 vs. 2019
change_df = top_airlines_flight_data_df.groupby(["Scheduled Operator", "Year"], as_index = True)
change_df2 = pd.DataFrame(change_df.sum())
change_df2
# Out:
#                                   Passengers_Total  Freight_Mail_Total
# Scheduled Operator          Year
# Air Caledonie International 2019          124493.0              1211.4
#                             2020           43294.0              1164.7
# Air Canada                  2019          409145.0              7500.7
#                             2020          139738.0              4848.7
# Air Chathams                2019             742.0                 2.1
# ...                                            ...                 ...
# Vietnam Airlines            2020          123978.0             11515.5
# Virgin Australia            2019         2837821.0             29096.5
#                             2020          871235.0              8450.6
# Xiamen Airlines             2019          218499.0             12083.0
#                             2020           62126.0              6037.9
#
# [130 rows x 2 columns]

# %%
#Calculate change and save into list
passengers_totals_list = change_df2["Passengers_Total"].tolist()

#Calculate total passengers (in and out) % change between 2019 vs 2020
passenger_change_list = [round((passengers_totals_list[i+1]-passengers_totals_list[i]) / passengers_totals_list[i],2)*100  1 for i in range(len(passengers_totals_list)-1)]

# Discard perecentage result from different airline
passenger_percentage_change_list = passenger_change_list[::2] #ignores every second element in the list
passenger_percentage_change_list
# Out:
# [-65.0,
#  -66.0,
#  53.0,
#  -79.0,
#  -60.0,
#  -65.0,
#  -66.0,
#  -66.0,
#  -70.0,
#  -70.0,
#  -50.0,
#  -72.0,
#  -65.0,
#  -77.0,
#  -79.0,
#  -65.0,
#  -74.0,
#  -71.0,
#  -68.0,
#  -73.0,
#  -72.0,
#  808.0,
#  -68.0,
#  -81.0,
#  -68.0,
#  -69.0,
#  -56.00000000000001,
#  -72.0,
#  -71.0,
#  -85.0,
#  -72.0,
#  -73.0,
#  -69.0,
#  -69.0,
#  -73.0,
#  -68.0,
#  -72.0,
#  -67.0,
#  -71.0,
#  -69.0,
#  -65.0,
#  -70.0,
#  -56.00000000000001,
#  -63.0,
#  -69.0,
#  -56.99999999999999,
#  -79.0,
#  -68.0,
#  -70.0,
#  -69.0,
#  -72.0,
#  -63.0,
#  -26.0,
#  -66.0,
#  -70.0,
#  -57.99999999999999,
#  -68.0,
#  -69.0,
#  -72.0]

# %%
#Calculate change and save into list
freight_mail_totals_list = change_df2["Freight_Mail_Total"].tolist()

#Calculate total passengers (in and out) % change between 2019 vs 2020
freight_mail_list = [round((freight_mail_totals_list[i+1]-freight_mail_totals_list[i]) / freight_mail_totals_list[i],2)*100 for i in range(len(freight_mail_totals_list)-1)]

# Discard perecentage result from different airline
freight_mail_percentage_change_list = freight_mail_list[::2] #ignores every second element in the list
freight_mail_percentage_change_list
# Out:
# [-30.0, -15.0, -15.0, -72.0, -33.0, -33.0]

# %%
# Create new dataframe comparing passenger and cargo numbers between 2019 vs 2020
top_airlines_combined_list = top_airlines_combined_list.sort_values() #Arrange alphabetically to ensure results match up
airline_strategy_change_df = pd.DataFrame({
    "Scheduled_Operator":top_airlines_combined_list,
    "Change_in_Passengers":passenger_percentage_change_list,
    "Change_in_Freight_Mail":freight_mail_percentage_change_list
    })

airline_strategy_change_df
# Out:
#        Scheduled_Operator  Change_in_Passengers  Change_in_Freight_Mail
# 0         Air New Zealand                 -66.0                   -30.0
# 1  Cathay Pacific Airways                 -74.0                   -15.0
# 2                Emirates                 -68.0                   -15.0
# 3                 Jetstar                 -69.0                   -72.0
# 4          Qantas Airways                 -70.0                   -33.0
# 5      Singapore Airlines                 -70.0                   -33.0

# %%
#Plot Change in Passengers
fig, ax = plt.subplots(figsize=(30,10)) 
plt.bar(top_airlines_combined_list, passenger_percentage_change_list,  color="b", align="center")
plt.title("2020 vs 2019 Change in Passengers",  fontsize=30)
plt.xlabel("Top Airlines", fontsize=25)
plt.ylabel("Percentage (%)", fontsize=25)
plt.xticks(ticks=[0,1,2,3,4,5],labels=top_airlines_combined_list, fontsize=25)
plt.yticks(fontsize=20)
# Out:
# (array([-80., -70., -60., -50., -40., -30., -20., -10.,   0.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
### Observation: All airlines dropped passenger travel by an average of 70%. Cathay Pacific had the largest change in number of passengers flying at -74%. But marginally above average

# %%
#Plot Change in Cargo
fig, ax = plt.subplots(figsize=(30,10))
plt.bar(top_airlines_combined_list, freight_mail_percentage_change_list, color="g", align="center")
plt.title("2020 vs 2019 Change in Freight & Mail", fontsize=30)
plt.xlabel("Top Airlines", fontsize=25)
plt.ylabel("Percentage (%)", fontsize=25)
plt.xticks(ticks=[0,1,2,3,4,5],labels=top_airlines_combined_list, fontsize=25)
plt.yticks(fontsize=20)
# Out:
# (array([-80., -70., -60., -50., -40., -30., -20., -10.,   0.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#Alternative Bar Cluster Plot Visualisation
matplotlib.style.use('ggplot')
df = airline_strategy_change_df
fig, ax = plt.subplots(figsize=(30,10))
df[['Change_in_Passengers']].plot.bar(stacked=True, width=0.2, position=1.5, colormap="winter", ax=ax, alpha=0.7)
df[['Change_in_Freight_Mail']].plot.bar(stacked=True, width=0.2, position=0.5, colormap="summer", ax=ax, alpha=0.7)
plt.legend(loc="best", fontsize=18)
plt.title("2020 vs 2019 Percentage Decrease in Performance", fontsize=30)
plt.xlabel("Top Airlines", fontsize=25)
plt.ylabel("Percentage (%)", fontsize=25)
plt.xticks(ticks=[0,1,2,3,4,5],labels=top_airlines_combined_list, fontsize=25)
plt.yticks(fontsize=20)
plt.show()

# %%
### Observation: Data shows that Jetstar its passengers and cargo numbers BOTH slumped by ~70%.
